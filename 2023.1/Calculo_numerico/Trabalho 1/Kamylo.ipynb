# %% [markdown]
# # <font color=green>Trabalhando com imagens</font>

# %%
import numpy as np
import matplotlib.pyplot as plt
const = 1.0/255 # Fator de conversão para as imagens

# %%
# %%timeit
image = np.load('ufsc_j.npy')
image2 = image[:]

cor_r, cor_g, cor_b = 0, 0, 0 # Número entre 0 e 255

for a in range(0, len(image2)):
    for b in range(0, len(image2[a])):
        # Alterando na imagem 2 e multiplicando pela const para o numero ficar entre 0 e 1
        image2[a,b] = (image2[a,b,0] + image2[a,b,1] + image2[a,b,2])/3.0
        
plt.imshow(image2)
# Out:
# 1.11 s ± 50.5 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
